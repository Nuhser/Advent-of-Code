# %% [markdown]
# # Day 16: Packet Decoder
#
# As you leave the cave and reach open waters, you receive a transmission from the Elves back on the ship.
#
# The transmission was sent using the Buoyancy Interchange Transmission System (BITS), a method of packing numeric expressions into a binary sequence. Your submarine's computer has saved the transmission in [hexadecimal](https://en.wikipedia.org/wiki/Hexadecimal) (your puzzle input).
#
# The first step of decoding the message is to convert the hexadecimal representation into binary. Each character of hexadecimal corresponds to four bits of binary data:
#
# ```
# 0 = 0000
# 1 = 0001
# 2 = 0010
# 3 = 0011
# 4 = 0100
# 5 = 0101
# 6 = 0110
# 7 = 0111
# 8 = 1000
# 9 = 1001
# A = 1010
# B = 1011
# C = 1100
# D = 1101
# E = 1110
# F = 1111
# ```
#
# The BITS transmission contains a single **packet** at its outermost layer which itself contains many other packets. The hexadecimal representation of this packet might encode a few extra `0` bits at the end; these are not part of the transmission and should be ignored.
#
# Every packet begins with a standard header: the first three bits encode the packet **version**, and the next three bits encode the packet **type ID**. These two values are numbers; all numbers encoded in any packet are represented as binary with the most significant bit first. For example, a version encoded as the binary sequence `100` represents the number `4`.
#
# Packets with type ID `4` represent a **literal value**. Literal value packets encode a single binary number. To do this, the binary number is padded with leading zeroes until its length is a multiple of four bits, and then it is broken into groups of four bits. Each group is prefixed by a `1` bit except the last group, which is prefixed by a `0` bit. These groups of five bits immediately follow the packet header. For example, the hexadecimal string `D2FE28` becomes:
#
# ```
# 110100101111111000101000
# VVVTTTAAAAABBBBBCCCCC
# ```
#
# Below each bit is a label indicating its purpose:
#
# - The three bits labeled `V` (`110`) are the packet version, `6`.
# - The three bits labeled `T` (`100`) are the packet type ID, `4`, which means the packet is a literal value.
# - The five bits labeled `A` (`10111`) start with a `1` (not the last group, keep reading) and contain the first four bits of the number, `0111`.
# - The five bits labeled `B` (`11110`) start with a `1` (not the last group, keep reading) and contain four more bits of the number, `1110`.
# - The five bits labeled `C` (`00101`) start with a `0` (last group, end of packet) and contain the last four bits of the number, `0101`.
# - The three unlabeled `0` bits at the end are extra due to the hexadecimal representation and should be ignored.
#
# So, this packet represents a literal value with binary representation `011111100101`, which is `2021` in decimal.
#
# Every other type of packet (any packet with a type ID other than `4`) represent an **operator** that performs some calculation on one or more sub-packets contained within. Right now, the specific operations aren't important; focus on parsing the hierarchy of sub-packets.
#
# An operator packet contains one or more packets. To indicate which subsequent binary data represents its sub-packets, an operator packet can use one of two modes indicated by the bit immediately after the packet header; this is called the **length type ID**:
#
# - If the length type ID is `0`, then the next **15** bits are a number that represents the **total length in bits** of the sub-packets contained by this packet.
# - If the length type ID is `1`, then the next **11** bits are a number that represents the **number of sub-packets immediately contained** by this packet.
#
# Finally, after the length type ID bit and the 15-bit or 11-bit field, the sub-packets appear.
#
# For example, here is an operator packet (hexadecimal string `38006F45291200`) with length type ID `0` that contains two sub-packets:
#
# ```
# 00111000000000000110111101000101001010010001001000000000
# VVVTTTILLLLLLLLLLLLLLLAAAAAAAAAAABBBBBBBBBBBBBBBB
# ```
#
# - The three bits labeled `V` (`001`) are the packet version, `1`.
# - The three bits labeled `T` (`110`) are the packet type ID, `6`, which means the packet is an operator.
# - The bit labeled `I` (`0`) is the length type ID, which indicates that the length is a 15-bit number representing the number of bits in the sub-packets.
# - The 15 bits labeled `L` (`000000000011011`) contain the length of the sub-packets in bits, `27`.
# - The 11 bits labeled `A` contain the first sub-packet, a literal value representing the number `10`.
# - The 16 bits labeled `B` contain the second sub-packet, a literal value representing the number `20`.
#
# After reading 11 and 16 bits of sub-packet data, the total length indicated in `L` (27) is reached, and so parsing of this packet stops.
#
# As another example, here is an operator packet (hexadecimal string `EE00D40C823060`) with length type ID `1` that contains three sub-packets:
#
# ```
# 11101110000000001101010000001100100000100011000001100000
# VVVTTTILLLLLLLLLLLAAAAAAAAAAABBBBBBBBBBBCCCCCCCCCCC
# ```
#
# - The three bits labeled `V` (`111`) are the packet version, `7`.
# - The three bits labeled `T` (`011`) are the packet type ID, `3`, which means the packet is an operator.
# - The bit labeled `I` (`1`) is the length type ID, which indicates that the length is a 11-bit number representing the number of sub-packets.
# - The 11 bits labeled `L` (`00000000011`) contain the number of sub-packets, `3`.
# - The 11 bits labeled `A` contain the first sub-packet, a literal value representing the number `1`.
# - The 11 bits labeled `B` contain the second sub-packet, a literal value representing the number `2`.
# - The 11 bits labeled `C` contain the third sub-packet, a literal value representing the number `3`.
#
# After reading 3 complete sub-packets, the number of sub-packets indicated in `L` (3) is reached, and so parsing of this packet stops.
#
# For now, parse the hierarchy of the packets throughout the transmission and **add up all of the version numbers**.
#
# Here are a few more examples of hexadecimal-encoded transmissions:
#
# - `8A004A801A8002F478` represents an operator packet (version 4) which contains an operator packet (version 1) which contains an operator packet (version 5) which contains a literal value (version 6); this packet has a version sum of **`16`**.
# - `620080001611562C8802118E34` represents an operator packet (version 3) which contains two sub-packets; each sub-packet is an operator packet that contains two literal values. This packet has a version sum of **`12`**.
# - `C0015000016115A2E0802F182340` has the same structure as the previous example, but the outermost packet uses a different length type ID. This packet has a version sum of **`23`**.
# - `A0016C880162017C3686B18A3D4780` is an operator packet that contains an operator packet that contains an operator packet that contains five literal values; it has a version sum of **`31`**.
#
# Decode the structure of your hexadecimal-encoded BITS transmission; **what do you get if you add up the version numbers in all packets?**

# %%
import aoc_util as aoc

def parse_packets(bin_code: str, max_packets_size: int=0) -> tuple[list[dict], int]:
    packets = []
    current_pos = 0

    while current_pos < len(bin_code) and "1" in bin_code[current_pos :]:
        # get packet version
        packet = {}
        packet["version"] = int(bin_code[current_pos : current_pos+3], base=2)
        current_pos += 3

        # get packet type id
        packet["id"] = int(bin_code[current_pos : current_pos+3], base=2)
        current_pos += 3

        # literal
        if packet["id"] == 4:
            number_string = ""
            while True:
                number_string += bin_code[current_pos+1 : current_pos+5]

                current_pos += 5

                if bin_code[current_pos-5] == "0":
                    break

            if number_string == "":
                number_string = "0"

            packet["number"] = int(number_string, base=2)
        
        # operator
        else:
            packet["length_type"] = int(bin_code[current_pos])
            current_pos += 1

            if packet["length_type"] == 0:
                packet["subpackets_length"] = int(bin_code[current_pos : current_pos+15], base=2)
                current_pos += 15
                packet["subpackets"], consumed_bits = parse_packets(bin_code[current_pos : current_pos+packet["subpackets_length"]])
            elif packet["length_type"] == 1:
                packet["subpackets_length"] = int(bin_code[current_pos : current_pos+11], base=2)
                current_pos += 11
                packet["subpackets"], consumed_bits = parse_packets(bin_code[current_pos :], packet["subpackets_length"])
            else:
                raise RuntimeError(f"Unsupported Length Type: {packet['length_type']}")

            current_pos += consumed_bits

        packets.append(packet)

        if (max_packets_size > 0) and (len(packets) >= max_packets_size):
            break

    return packets, current_pos

def get_version_sum(packets: list[dict]) -> int:
    version_sum = 0
    for packet in packets:
        version_sum += packet["version"]

        if "subpackets" in packet:
            version_sum += get_version_sum(packet["subpackets"])

    return version_sum


# read puzzle input and convert to binary string
hex_code = aoc.parse_input(aoc.get_puzzle_input(16))[0]
bin_code = "".join(aoc.convert_hex_to_bin(char) for char in hex_code)

# print(hex_code)
# print(bin_code)

packets, _ = parse_packets(bin_code)

# import json
# print(json.dumps(packets, indent=4))

print(f"Sum of packet versions: {get_version_sum(packets)}")
# Out:
# [
#     {
#         "version": 3,
#         "id": 0,
#         "length_type": 1,
#         "subpackets_length": 53,
#         "subpackets": [
#             {
#                 "version": 7,
#                 "id": 3,
#                 "length_type": 0,
#                 "subpackets_length": 93,
#                 "subpackets": [
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 2373565
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 10
#                     },
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 2996012531
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 3,
#                 "length_type": 0,
#                 "subpackets_length": 11,
#                 "subpackets": [
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 15
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 65413
#                     },
#                     {
#                         "version": 5,
#                         "id": 6,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 5,
#                                 "id": 4,
#                                 "number": 149
#                             },
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 149
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 2,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 95,
#                 "subpackets": [
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 591
#                     },
#                     {
#                         "version": 0,
#                         "id": 7,
#                         "length_type": 0,
#                         "subpackets_length": 52,
#                         "subpackets": [
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 167
#                             },
#                             {
#                                 "version": 4,
#                                 "id": 4,
#                                 "number": 8716114
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 4,
#                 "id": 0,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 35
#                     },
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 3985
#                     }
#                 ]
#             },
#             {
#                 "version": 5,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 48,
#                 "subpackets": [
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 45
#                     },
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 222
#                     },
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 180
#                     }
#                 ]
#             },
#             {
#                 "version": 6,
#                 "id": 4,
#                 "number": 11
#             },
#             {
#                 "version": 5,
#                 "id": 4,
#                 "number": 143
#             },
#             {
#                 "version": 2,
#                 "id": 4,
#                 "number": 3
#             },
#             {
#                 "version": 4,
#                 "id": 4,
#                 "number": 3655
#             },
#             {
#                 "version": 5,
#                 "id": 0,
#                 "length_type": 0,
#                 "subpackets_length": 11,
#                 "subpackets": [
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 12
#                     }
#                 ]
#             },
#             {
#                 "version": 5,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 1055381497179
#                     },
#                     {
#                         "version": 3,
#                         "id": 5,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 2,
#                                 "id": 0,
#                                 "length_type": 1,
#                                 "subpackets_length": 3,
#                                 "subpackets": [
#                                     {
#                                         "version": 2,
#                                         "id": 4,
#                                         "number": 6
#                                     },
#                                     {
#                                         "version": 3,
#                                         "id": 4,
#                                         "number": 14
#                                     },
#                                     {
#                                         "version": 6,
#                                         "id": 4,
#                                         "number": 9
#                                     }
#                                 ]
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 0,
#                                 "length_type": 1,
#                                 "subpackets_length": 3,
#                                 "subpackets": [
#                                     {
#                                         "version": 5,
#                                         "id": 4,
#                                         "number": 9
#                                     },
#                                     {
#                                         "version": 6,
#                                         "id": 4,
#                                         "number": 8
#                                     },
#                                     {
#                                         "version": 6,
#                                         "id": 4,
#                                         "number": 9
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 2,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 3,
#                         "id": 6,
#                         "length_type": 0,
#                         "subpackets_length": 42,
#                         "subpackets": [
#                             {
#                                 "version": 6,
#                                 "id": 4,
#                                 "number": 26925
#                             },
#                             {
#                                 "version": 5,
#                                 "id": 4,
#                                 "number": 243
#                             }
#                         ]
#                     },
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 203
#                     }
#                 ]
#             },
#             {
#                 "version": 0,
#                 "id": 4,
#                 "number": 14
#             },
#             {
#                 "version": 2,
#                 "id": 2,
#                 "length_type": 0,
#                 "subpackets_length": 57,
#                 "subpackets": [
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 172
#                     },
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 76461834
#                     }
#                 ]
#             },
#             {
#                 "version": 2,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 126,
#                 "subpackets": [
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 119
#                     },
#                     {
#                         "version": 2,
#                         "id": 7,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 7,
#                                 "id": 4,
#                                 "number": 2578981728
#                             },
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 2578981728
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 4,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 159,
#                 "subpackets": [
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 916992
#                     },
#                     {
#                         "version": 6,
#                         "id": 6,
#                         "length_type": 0,
#                         "subpackets_length": 106,
#                         "subpackets": [
#                             {
#                                 "version": 4,
#                                 "id": 0,
#                                 "length_type": 0,
#                                 "subpackets_length": 33,
#                                 "subpackets": [
#                                     {
#                                         "version": 1,
#                                         "id": 4,
#                                         "number": 11
#                                     },
#                                     {
#                                         "version": 3,
#                                         "id": 4,
#                                         "number": 4
#                                     },
#                                     {
#                                         "version": 2,
#                                         "id": 4,
#                                         "number": 13
#                                     }
#                                 ]
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 0,
#                                 "length_type": 1,
#                                 "subpackets_length": 3,
#                                 "subpackets": [
#                                     {
#                                         "version": 0,
#                                         "id": 4,
#                                         "number": 12
#                                     },
#                                     {
#                                         "version": 3,
#                                         "id": 4,
#                                         "number": 3
#                                     },
#                                     {
#                                         "version": 1,
#                                         "id": 4,
#                                         "number": 11
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 4,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 80,
#                 "subpackets": [
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 168
#                     },
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 168
#                     },
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 231
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 204
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 145
#                     }
#                 ]
#             },
#             {
#                 "version": 3,
#                 "id": 2,
#                 "length_type": 1,
#                 "subpackets_length": 1,
#                 "subpackets": [
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 22
#                     }
#                 ]
#             },
#             {
#                 "version": 1,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 76,
#                 "subpackets": [
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 5
#                     },
#                     {
#                         "version": 5,
#                         "id": 5,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 4,
#                                 "id": 4,
#                                 "number": 20484
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 2972
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 6,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 116,
#                 "subpackets": [
#                     {
#                         "version": 3,
#                         "id": 5,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 121310408
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 121310408
#                             }
#                         ]
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 107
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 4,
#                 "number": 2
#             },
#             {
#                 "version": 7,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 0,
#                         "id": 7,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 181284836
#                             },
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 2893
#                             }
#                         ]
#                     },
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 3355
#                     }
#                 ]
#             },
#             {
#                 "version": 3,
#                 "id": 0,
#                 "length_type": 0,
#                 "subpackets_length": 93,
#                 "subpackets": [
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 422763583939
#                     },
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 7
#                     },
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 21560
#                     }
#                 ]
#             },
#             {
#                 "version": 6,
#                 "id": 3,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 721753
#                     },
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 918579
#                     }
#                 ]
#             },
#             {
#                 "version": 0,
#                 "id": 4,
#                 "number": 3755
#             },
#             {
#                 "version": 2,
#                 "id": 0,
#                 "length_type": 0,
#                 "subpackets_length": 157,
#                 "subpackets": [
#                     {
#                         "version": 4,
#                         "id": 1,
#                         "length_type": 1,
#                         "subpackets_length": 3,
#                         "subpackets": [
#                             {
#                                 "version": 7,
#                                 "id": 4,
#                                 "number": 6
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 8
#                             },
#                             {
#                                 "version": 2,
#                                 "id": 4,
#                                 "number": 9
#                             }
#                         ]
#                     },
#                     {
#                         "version": 1,
#                         "id": 1,
#                         "length_type": 0,
#                         "subpackets_length": 33,
#                         "subpackets": [
#                             {
#                                 "version": 5,
#                                 "id": 4,
#                                 "number": 9
#                             },
#                             {
#                                 "version": 5,
#                                 "id": 4,
#                                 "number": 13
#                             },
#                             {
#                                 "version": 2,
#                                 "id": 4,
#                                 "number": 11
#                             }
#                         ]
#                     },
#                     {
#                         "version": 5,
#                         "id": 1,
#                         "length_type": 1,
#                         "subpackets_length": 3,
#                         "subpackets": [
#                             {
#                                 "version": 3,
#                                 "id": 4,
#                                 "number": 2
#                             },
#                             {
#                                 "version": 3,
#                                 "id": 4,
#                                 "number": 14
#                             },
#                             {
#                                 "version": 2,
#                                 "id": 4,
#                                 "number": 10
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 5,
#                 "id": 0,
#                 "length_type": 1,
#                 "subpackets_length": 4,
#                 "subpackets": [
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 988120
#                     },
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 8947
#                     },
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 11733
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 9
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 115,
#                 "subpackets": [
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 1153
#                     },
#                     {
#                         "version": 4,
#                         "id": 5,
#                         "length_type": 0,
#                         "subpackets_length": 72,
#                         "subpackets": [
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 1142126506
#                             },
#                             {
#                                 "version": 2,
#                                 "id": 4,
#                                 "number": 29116
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 0,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 153,
#                 "subpackets": [
#                     {
#                         "version": 2,
#                         "id": 0,
#                         "length_type": 1,
#                         "subpackets_length": 3,
#                         "subpackets": [
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 11
#                             },
#                             {
#                                 "version": 2,
#                                 "id": 4,
#                                 "number": 12
#                             },
#                             {
#                                 "version": 3,
#                                 "id": 4,
#                                 "number": 6
#                             }
#                         ]
#                     },
#                     {
#                         "version": 0,
#                         "id": 0,
#                         "length_type": 1,
#                         "subpackets_length": 3,
#                         "subpackets": [
#                             {
#                                 "version": 7,
#                                 "id": 4,
#                                 "number": 12
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 15
#                             },
#                             {
#                                 "version": 5,
#                                 "id": 4,
#                                 "number": 5
#                             }
#                         ]
#                     },
#                     {
#                         "version": 7,
#                         "id": 0,
#                         "length_type": 1,
#                         "subpackets_length": 3,
#                         "subpackets": [
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 8
#                             },
#                             {
#                                 "version": 5,
#                                 "id": 4,
#                                 "number": 4
#                             },
#                             {
#                                 "version": 7,
#                                 "id": 4,
#                                 "number": 10
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 4,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 91,
#                 "subpackets": [
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 12105
#                     },
#                     {
#                         "version": 2,
#                         "id": 5,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 227
#                             },
#                             {
#                                 "version": 4,
#                                 "id": 4,
#                                 "number": 418797
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 0,
#                 "id": 2,
#                 "length_type": 1,
#                 "subpackets_length": 3,
#                 "subpackets": [
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 26544091
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 1183
#                     },
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 3813
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 0,
#                         "id": 5,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 160
#                             },
#                             {
#                                 "version": 2,
#                                 "id": 4,
#                                 "number": 160
#                             }
#                         ]
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 6008502
#                     }
#                 ]
#             },
#             {
#                 "version": 5,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 75
#                     },
#                     {
#                         "version": 7,
#                         "id": 6,
#                         "length_type": 0,
#                         "subpackets_length": 77,
#                         "subpackets": [
#                             {
#                                 "version": 4,
#                                 "id": 4,
#                                 "number": 63804
#                             },
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 61776841880
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 6,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 4,
#                 "subpackets": [
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 132
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 221
#                     },
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 206
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 27
#                     }
#                 ]
#             },
#             {
#                 "version": 4,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 96,
#                 "subpackets": [
#                     {
#                         "version": 7,
#                         "id": 5,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 6,
#                                 "id": 4,
#                                 "number": 165
#                             },
#                             {
#                                 "version": 1,
#                                 "id": 4,
#                                 "number": 37623
#                             }
#                         ]
#                     },
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 2941040
#                     }
#                 ]
#             },
#             {
#                 "version": 1,
#                 "id": 0,
#                 "length_type": 0,
#                 "subpackets_length": 140,
#                 "subpackets": [
#                     {
#                         "version": 5,
#                         "id": 4,
#                         "number": 41297
#                     },
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 600
#                     },
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 1881
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 13468
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 934987761
#                     }
#                 ]
#             },
#             {
#                 "version": 5,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 16,
#                 "subpackets": [
#                     {
#                         "version": 5,
#                         "id": 4,
#                         "number": 152
#                     }
#                 ]
#             },
#             {
#                 "version": 0,
#                 "id": 4,
#                 "number": 80
#             },
#             {
#                 "version": 0,
#                 "id": 3,
#                 "length_type": 1,
#                 "subpackets_length": 4,
#                 "subpackets": [
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 10709961
#                     },
#                     {
#                         "version": 5,
#                         "id": 4,
#                         "number": 6
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 201
#                     },
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 205
#                     }
#                 ]
#             },
#             {
#                 "version": 1,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 84715928
#                     },
#                     {
#                         "version": 0,
#                         "id": 5,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 3,
#                                 "id": 0,
#                                 "length_type": 0,
#                                 "subpackets_length": 33,
#                                 "subpackets": [
#                                     {
#                                         "version": 2,
#                                         "id": 4,
#                                         "number": 6
#                                     },
#                                     {
#                                         "version": 1,
#                                         "id": 4,
#                                         "number": 15
#                                     },
#                                     {
#                                         "version": 0,
#                                         "id": 4,
#                                         "number": 3
#                                     }
#                                 ]
#                             },
#                             {
#                                 "version": 2,
#                                 "id": 0,
#                                 "length_type": 1,
#                                 "subpackets_length": 3,
#                                 "subpackets": [
#                                     {
#                                         "version": 7,
#                                         "id": 4,
#                                         "number": 7
#                                     },
#                                     {
#                                         "version": 4,
#                                         "id": 4,
#                                         "number": 6
#                                     },
#                                     {
#                                         "version": 5,
#                                         "id": 4,
#                                         "number": 4
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 0,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 66,
#                 "subpackets": [
#                     {
#                         "version": 6,
#                         "id": 6,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 6,
#                                 "id": 4,
#                                 "number": 1209
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 38
#                             }
#                         ]
#                     },
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 1
#                     }
#                 ]
#             },
#             {
#                 "version": 5,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 145,
#                 "subpackets": [
#                     {
#                         "version": 5,
#                         "id": 7,
#                         "length_type": 1,
#                         "subpackets_length": 2,
#                         "subpackets": [
#                             {
#                                 "version": 3,
#                                 "id": 0,
#                                 "length_type": 0,
#                                 "subpackets_length": 33,
#                                 "subpackets": [
#                                     {
#                                         "version": 0,
#                                         "id": 4,
#                                         "number": 10
#                                     },
#                                     {
#                                         "version": 7,
#                                         "id": 4,
#                                         "number": 7
#                                     },
#                                     {
#                                         "version": 7,
#                                         "id": 4,
#                                         "number": 12
#                                     }
#                                 ]
#                             },
#                             {
#                                 "version": 1,
#                                 "id": 0,
#                                 "length_type": 1,
#                                 "subpackets_length": 3,
#                                 "subpackets": [
#                                     {
#                                         "version": 3,
#                                         "id": 4,
#                                         "number": 14
#                                     },
#                                     {
#                                         "version": 6,
#                                         "id": 4,
#                                         "number": 6
#                                     },
#                                     {
#                                         "version": 5,
#                                         "id": 4,
#                                         "number": 10
#                                     }
#                                 ]
#                             }
#                         ]
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 2467
#                     }
#                 ]
#             },
#             {
#                 "version": 1,
#                 "id": 3,
#                 "length_type": 1,
#                 "subpackets_length": 1,
#                 "subpackets": [
#                     {
#                         "version": 4,
#                         "id": 3,
#                         "length_type": 1,
#                         "subpackets_length": 1,
#                         "subpackets": [
#                             {
#                                 "version": 5,
#                                 "id": 3,
#                                 "length_type": 0,
#                                 "subpackets_length": 368,
#                                 "subpackets": [
#                                     {
#                                         "version": 6,
#                                         "id": 0,
#                                         "length_type": 1,
#                                         "subpackets_length": 1,
#                                         "subpackets": [
#                                             {
#                                                 "version": 2,
#                                                 "id": 1,
#                                                 "length_type": 1,
#                                                 "subpackets_length": 1,
#                                                 "subpackets": [
#                                                     {
#                                                         "version": 2,
#                                                         "id": 1,
#                                                         "length_type": 0,
#                                                         "subpackets_length": 310,
#                                                         "subpackets": [
#                                                             {
#                                                                 "version": 1,
#                                                                 "id": 3,
#                                                                 "length_type": 1,
#                                                                 "subpackets_length": 1,
#                                                                 "subpackets": [
#                                                                     {
#                                                                         "version": 6,
#                                                                         "id": 1,
#                                                                         "length_type": 0,
#                                                                         "subpackets_length": 270,
#                                                                         "subpackets": [
#                                                                             {
#                                                                                 "version": 6,
#                                                                                 "id": 1,
#                                                                                 "length_type": 0,
#                                                                                 "subpackets_length": 248,
#                                                                                 "subpackets": [
#                                                                                     {
#                                                                                         "version": 3,
#                                                                                         "id": 1,
#                                                                                         "length_type": 1,
#                                                                                         "subpackets_length": 1,
#                                                                                         "subpackets": [
#                                                                                             {
#                                                                                                 "version": 0,
#                                                                                                 "id": 0,
#                                                                                                 "length_type": 0,
#                                                                                                 "subpackets_length": 208,
#                                                                                                 "subpackets": [
#                                                                                                     {
#                                                                                                         "version": 1,
#                                                                                                         "id": 2,
#                                                                                                         "length_type": 1,
#                                                                                                         "subpackets_length": 1,
#                                                                                                         "subpackets": [
#                                                                                                             {
#                                                                                                                 "version": 5,
#                                                                                                                 "id": 0,
#                                                                                                                 "length_type": 0,
#                                                                                                                 "subpackets_length": 168,
#                                                                                                                 "subpackets": [
#                                                                                                                     {
#                                                                                                                         "version": 2,
#                                                                                                                         "id": 1,
#                                                                                                                         "length_type": 1,
#                                                                                                                         "subpackets_length": 1,
#                                                                                                                         "subpackets": [
#                                                                                                                             {
#                                                                                                                                 "version": 1,
# ...
#                                                                                                                                                         "version": 1,
#                                                                                                                                                         "id": 0,
#                                                                                                                                                         "length_type": 1,
#                                                                                                                                                         "subpackets_length": 1,
#                                                                                                                                                         "subpackets": [
#                                                                                                                                                             {
#                                                                                                                                                                 "version": 4,
#                                                                                                                                                                 "id": 0,
#                                                                                                                                                                 "length_type": 0,
#                                                                                                                                                                 "subpackets_length": 44,
#                                                                                                                                                                 "subpackets": [
#                                                                                                                                                                     {
#                                                                                                                                                                         "version": 7,
#                                                                                                                                                                         "id": 1,
#                                                                                                                                                                         "length_type": 1,
#                                                                                                                                                                         "subpackets_length": 1,
#                                                                                                                                                                         "subpackets": [
#                                                                                                                                                                             {
#                                                                                                                                                                                 "version": 4,
#                                                                                                                                                                                 "id": 4,
#                                                                                                                                                                                 "number": 51595
#                                                                                                                                                                             }
#                                                                                                                                                                         ]
#                                                                                                                                                                     }
#                                                                                                                                                                 ]
#                                                                                                                                                             }
#                                                                                                                                                         ]
#                                                                                                                                                     }
#                                                                                                                                                 ]
#                                                                                                                                             }
#                                                                                                                                         ]
#                                                                                                                                     }
#                                                                                                                                 ]
#                                                                                                                             }
#                                                                                                                         ]
#                                                                                                                     }
#                                                                                                                 ]
#                                                                                                             }
#                                                                                                         ]
#                                                                                                     }
#                                                                                                 ]
#                                                                                             }
#                                                                                         ]
#                                                                                     }
#                                                                                 ]
#                                                                             }
#                                                                         ]
#                                                                     }
#                                                                 ]
#                                                             }
#                                                         ]
#                                                     }
#                                                 ]
#                                             }
#                                         ]
#                                     }
#                                 ]
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 4,
#                 "number": 8
#             },
#             {
#                 "version": 3,
#                 "id": 1,
#                 "length_type": 0,
#                 "subpackets_length": 159,
#                 "subpackets": [
#                     {
#                         "version": 0,
#                         "id": 6,
#                         "length_type": 0,
#                         "subpackets_length": 106,
#                         "subpackets": [
#                             {
#                                 "version": 5,
#                                 "id": 0,
#                                 "length_type": 1,
#                                 "subpackets_length": 3,
#                                 "subpackets": [
#                                     {
#                                         "version": 3,
#                                         "id": 4,
#                                         "number": 12
#                                     },
#                                     {
#                                         "version": 0,
#                                         "id": 4,
#                                         "number": 2
#                                     },
#                                     {
#                                         "version": 0,
#                                         "id": 4,
#                                         "number": 10
#                                     }
#                                 ]
#                             },
#                             {
#                                 "version": 5,
#                                 "id": 0,
#                                 "length_type": 0,
#                                 "subpackets_length": 33,
#                                 "subpackets": [
#                                     {
#                                         "version": 0,
#                                         "id": 4,
#                                         "number": 14
#                                     },
#                                     {
#                                         "version": 1,
#                                         "id": 4,
#                                         "number": 11
#                                     },
#                                     {
#                                         "version": 2,
#                                         "id": 4,
#                                         "number": 8
#                                     }
#                                 ]
#                             }
#                         ]
#                     },
#                     {
#                         "version": 5,
#                         "id": 4,
#                         "number": 497146
#                     }
#                 ]
#             },
#             {
#                 "version": 1,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 29
#                     },
#                     {
#                         "version": 1,
#                         "id": 6,
#                         "length_type": 0,
#                         "subpackets_length": 77,
#                         "subpackets": [
#                             {
#                                 "version": 6,
#                                 "id": 4,
#                                 "number": 39139
#                             },
#                             {
#                                 "version": 5,
#                                 "id": 4,
#                                 "number": 23730051848
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 1,
#                         "id": 6,
#                         "length_type": 0,
#                         "subpackets_length": 72,
#                         "subpackets": [
#                             {
#                                 "version": 2,
#                                 "id": 4,
#                                 "number": 11806681
#                             },
#                             {
#                                 "version": 0,
#                                 "id": 4,
#                                 "number": 11806681
#                             }
#                         ]
#                     },
#                     {
#                         "version": 4,
#                         "id": 4,
#                         "number": 16382499
#                     }
#                 ]
#             },
#             {
#                 "version": 5,
#                 "id": 2,
#                 "length_type": 0,
#                 "subpackets_length": 109,
#                 "subpackets": [
#                     {
#                         "version": 0,
#                         "id": 4,
#                         "number": 143781176
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 4
#                     },
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 13
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 3012243711
#                     }
#                 ]
#             },
#             {
#                 "version": 1,
#                 "id": 2,
#                 "length_type": 0,
#                 "subpackets_length": 150,
#                 "subpackets": [
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 182
#                     },
#                     {
#                         "version": 3,
#                         "id": 4,
#                         "number": 247667569
#                     },
#                     {
#                         "version": 5,
#                         "id": 4,
#                         "number": 36236
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 626693
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 7264055
#                     }
#                 ]
#             },
#             {
#                 "version": 7,
#                 "id": 4,
#                 "number": 4913
#             },
#             {
#                 "version": 7,
#                 "id": 3,
#                 "length_type": 1,
#                 "subpackets_length": 5,
#                 "subpackets": [
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 63257
#                     },
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 64469
#                     },
#                     {
#                         "version": 2,
#                         "id": 4,
#                         "number": 2220
#                     },
#                     {
#                         "version": 1,
#                         "id": 4,
#                         "number": 56
#                     },
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 6338993
#                     }
#                 ]
#             },
#             {
#                 "version": 6,
#                 "id": 1,
#                 "length_type": 1,
#                 "subpackets_length": 2,
#                 "subpackets": [
#                     {
#                         "version": 7,
#                         "id": 4,
#                         "number": 235
#                     },
#                     {
#                         "version": 6,
#                         "id": 4,
#                         "number": 133
#                     }
#                 ]
#             }
#         ]
#     }
# ]
# Sum of packet versions: 883
